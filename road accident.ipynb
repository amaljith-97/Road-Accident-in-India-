# %%
import pandas as pd

# %%
df = pd.read_csv('driverresponse.csv')

# %%
df.head()
# Out:
#    index  sno            stateut     region  regionid  alcintake2014  \
# 0      0    1     Andhra Pradesh      south         2            594
# 1      1    2  Arunachal Pradesh  northeast         5             11
# 2      2    3              Assam  northeast         5            613
# 3      3    4              Bihar      north         1           1680
# 4      4    5       Chhattisgarh     centre         9            335
#
#    overspeed2014  overtaking2014  lanejumping2014  wrongside2014  ...  \
# 0        12747.0             507              328            668  ...
# 1           16.0               0                0              0  ...
# 2         4596.0             129              104            156  ...
# 3         1496.0             278              236            308  ...
# 4         6720.0             188              313            266  ...
#
#    asleep2014  othercause2014  alcintake2016  overspeed2016  signalavoid2016  \
# ...

# %%
df.tail()
# Out:
#     index  sno       stateut     region  regionid  alcintake2014  \
# 31     31   32  D & N Haveli       west         4              1
# 32     32   33   Daman & Diu       west         4              0
# 33     33   34         Delhi      north         1             51
# 34     34   35   Lakshadweep  southwest         8              0
# 35     35   36    Puducherry      south         2             73
#
#     overspeed2014  overtaking2014  lanejumping2014  wrongside2014  ...  \
# 31           21.0               0                0              0  ...
# 32           21.0               2                2              1  ...
# 33            NaN               0                0              0  ...
# 34            1.0               0                0              0  ...
# 35          250.0             136                0              8  ...
#
#     asleep2014  othercause2014  alcintake2016  overspeed2016  signalavoid2016  \
# ...

# %%
df.shape
# Out:
# (36, 21)

# %%
df.columns
# Out:
# Index(['index', 'sno', 'stateut', 'region', 'regionid', 'alcintake2014',
#        'overspeed2014', 'overtaking2014', 'lanejumping2014', 'wrongside2014',
#        'signalavoid2014', 'asleep2014', 'othercause2014', 'alcintake2016',
#        'overspeed2016', 'signalavoid2016', 'wrongside2016', 'lanejumping2016',
#        'overtaking2016', 'asleep2016', 'othercause2016'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# index              0
# sno                0
# stateut            0
# region             0
# regionid           0
# alcintake2014      0
# overspeed2014      1
# overtaking2014     0
# lanejumping2014    0
# wrongside2014      0
# signalavoid2014    0
# asleep2014         0
# othercause2014     0
# alcintake2016      0
# overspeed2016      0
# signalavoid2016    0
# wrongside2016      0
# lanejumping2016    0
# overtaking2016     0
# asleep2016         0
# othercause2016     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            36 non-null     int64
#  1   sno              36 non-null     int64
#  2   stateut          36 non-null     object
#  3   region           36 non-null     object
#  4   regionid         36 non-null     int64
#  5   alcintake2014    36 non-null     int64
#  6   overspeed2014    35 non-null     float64
#  7   overtaking2014   36 non-null     int64
#  8   lanejumping2014  36 non-null     int64
#  9   wrongside2014    36 non-null     int64
#  10  signalavoid2014  36 non-null     int64
#  11  asleep2014       36 non-null     int64
#  12  othercause2014   36 non-null     int64
#  13  alcintake2016    36 non-null     int64
#  14  overspeed2016    36 non-null     int64
#  15  signalavoid2016  36 non-null     int64
#  16  wrongside2016    36 non-null     int64
# ...

# %%
df.describe()
# Out:
#            index        sno   regionid  alcintake2014  overspeed2014  \
# count  36.000000  36.000000  36.000000      36.000000      35.000000
# mean   17.500000  18.500000   4.000000     525.444444    5950.600000
# std    10.535654  10.535654   2.746426     767.133866    8677.731983
# min     0.000000   1.000000   1.000000       0.000000       0.000000
# 25%     8.750000   9.750000   1.750000      11.750000      72.500000
# 50%    17.500000  18.500000   4.000000      82.500000    2561.000000
# 75%    26.250000  27.250000   5.000000     706.500000    6493.000000
# max    35.000000  36.000000   9.000000    3540.000000   29790.000000
#
#        overtaking2014  lanejumping2014  wrongside2014  signalavoid2014  \
# count       36.000000        36.000000      36.000000        36.000000
# mean       312.833333       283.361111     302.000000        37.000000
# std        514.513279       462.370115     389.184642        81.196411
# ...

# %%
df.nunique()
# Out:
# index              36
# sno                36
# stateut            36
# region              9
# regionid            9
# alcintake2014      31
# overspeed2014      33
# overtaking2014     28
# lanejumping2014    26
# wrongside2014      29
# signalavoid2014    19
# asleep2014         19
# othercause2014     30
# alcintake2016      34
# overspeed2016      35
# signalavoid2016    22
# wrongside2016      33
# lanejumping2016    23
# overtaking2016     33
# asleep2016         24
# othercause2016     32
# dtype: int64

# %%
df = df.drop(['index','sno'],axis=1)

# %%
df= df.dropna()

# %%
df.isnull().sum()
# Out:
# stateut            0
# region             0
# regionid           0
# alcintake2014      0
# overspeed2014      0
# overtaking2014     0
# lanejumping2014    0
# wrongside2014      0
# signalavoid2014    0
# asleep2014         0
# othercause2014     0
# alcintake2016      0
# overspeed2016      0
# signalavoid2016    0
# wrongside2016      0
# lanejumping2016    0
# overtaking2016     0
# asleep2016         0
# othercause2016     0
# dtype: int64

# %%
df['region'].unique()
# Out:
# array(['south', 'northeast', 'north', 'centre', 'west', 'east',
#        'northwest', 'southeast', 'southwest'], dtype=object)

# %%
df['region'].value_counts()
# Out:
# north        8
# northeast    6
# south        5
# centre       5
# west         5
# east         3
# northwest    1
# southeast    1
# southwest    1
# Name: region, dtype: int64

# %% [markdown]
# ## data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=[20,8])
print ('countplot for Region')
sns.countplot(df['region'],data = df,palette = 'rocket')
plt.xticks(rotation=0)
plt.show()
# Out:
# countplot for Region

# %%
plt.figure(figsize=[20,8])
print('pieplot for Region')
df['region'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.xticks(rotation=0)
plt.show()
# Out:
# pieplot for Region

# %%
df['regionid'].unique()
# Out:
# array([2, 5, 1, 9, 4, 3, 6, 7, 8], dtype=int64)

# %%
df['regionid'].value_counts()
# Out:
# 1    8
# 5    6
# 2    5
# 9    5
# 4    5
# 3    3
# 6    1
# 7    1
# 8    1
# Name: regionid, dtype: int64

# %%
plt.figure(figsize=[20,8])
print('countplot of RegionID')
sns.countplot(df['regionid'],data = df, palette='mako')
plt.xticks(rotation = 0)
plt.show()
# Out:
# countplot of RegionID

# %%
plt.figure(figsize=[20,8])
print ('pieplot for RegionID')
df['regionid'].value_counts().plot(kind='pie',autopct= '%1.1f%%')
plt.xticks(rotation=0)
plt.show()
# Out:
# pieplot for RegionID

# %%
plt.figure(figsize=[20,8])
print('Pairplot')
sns.pairplot(df,hue='region')
plt.xticks(rotation=0)
plt.show()
# Out:
# Pairplot

# %%
import numpy as np

# %%
plt.figure(figsize=[20,12],dpi=250)
plt.title('correlation graph', fontsize = 14)
matrix = np.triu(df.corr())
sns.heatmap(df.corr(),annot=True,cmap = 'coolwarm', cbar = False)
plt.show()

# %%
import plotly.express as px

# %%
fig = px.box(df,x='region',y='alcintake2014')
fig.show()
# Out:
# <div>                            <div id="3ce5e017-197c-4808-87b9-223a466e282e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ce5e017-197c-4808-87b9-223a466e282e")) {                    Plotly.newPlot(                        "3ce5e017-197c-4808-87b9-223a466e282e",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>alcintake2014=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north",
# ...

# %%
fig = px.box(df,x='region',y='overspeed2014')
fig.show()
# Out:
# <div>                            <div id="a7a853ba-71d1-48c5-bde5-dab559668ae3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7a853ba-71d1-48c5-bde5-dab559668ae3")) {                    Plotly.newPlot(                        "a7a853ba-71d1-48c5-bde5-dab559668ae3",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>overspeed2014=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north",
# ...

# %%
fig = px.box(df,x='region',y='overtaking2014')
fig.show()
# Out:
# <div>                            <div id="eb13028e-5f66-4bb6-99f9-4d221e06f9f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb13028e-5f66-4bb6-99f9-4d221e06f9f3")) {                    Plotly.newPlot(                        "eb13028e-5f66-4bb6-99f9-4d221e06f9f3",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>overtaking2014=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north"
# ...

# %%
fig = px.box(df,x='region',y='lanejumping2014')
fig.show()
# Out:
# <div>                            <div id="ac5f3640-dd41-4a47-a17e-c7b9e1ed72cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac5f3640-dd41-4a47-a17e-c7b9e1ed72cd")) {                    Plotly.newPlot(                        "ac5f3640-dd41-4a47-a17e-c7b9e1ed72cd",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>lanejumping2014=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north
# ...

# %%
fig = px.box(df,x='region',y='wrongside2014')
fig.show()
# Out:
# <div>                            <div id="70f587be-f731-4be4-9967-4fc2d7e528d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70f587be-f731-4be4-9967-4fc2d7e528d6")) {                    Plotly.newPlot(                        "70f587be-f731-4be4-9967-4fc2d7e528d6",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>wrongside2014=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north",
# ...

# %%
fig= px.box(df,x='region',y='signalavoid2014')
fig.show()
# Out:
# <div>                            <div id="e3e64ae2-31f4-4e2e-8e3f-330d290bfb02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3e64ae2-31f4-4e2e-8e3f-330d290bfb02")) {                    Plotly.newPlot(                        "e3e64ae2-31f4-4e2e-8e3f-330d290bfb02",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>signalavoid2014=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north
# ...

# %%
fig = px.box(df,x='region',y='asleep2014')
fig.show()
# Out:
# <div>                            <div id="37c9041c-35d4-425f-9b94-a7319209b7b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37c9041c-35d4-425f-9b94-a7319209b7b7")) {                    Plotly.newPlot(                        "37c9041c-35d4-425f-9b94-a7319209b7b7",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>asleep2014=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north","no
# ...

# %%
fig =px.box(df,x='region',y='othercause2014') 
fig.show()
# Out:
# <div>                            <div id="f17cda09-8336-4752-a751-9b38b2e047f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f17cda09-8336-4752-a751-9b38b2e047f7")) {                    Plotly.newPlot(                        "f17cda09-8336-4752-a751-9b38b2e047f7",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>othercause2014=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north"
# ...

# %%
fig = px.box(df,x='region',y='alcintake2016')
fig.show()
# Out:
# <div>                            <div id="f06c8e52-8d80-4090-b378-a88278ab3afe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f06c8e52-8d80-4090-b378-a88278ab3afe")) {                    Plotly.newPlot(                        "f06c8e52-8d80-4090-b378-a88278ab3afe",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>alcintake2016=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north",
# ...

# %%
fig=px.box(df,x='region',y='overspeed2016')
fig.show()
# Out:
# <div>                            <div id="139671b8-290c-4bc3-8d4a-ed6b0cf19609" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("139671b8-290c-4bc3-8d4a-ed6b0cf19609")) {                    Plotly.newPlot(                        "139671b8-290c-4bc3-8d4a-ed6b0cf19609",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>overspeed2016=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north",
# ...

# %%
fig = px.box(df,x='region',y='signalavoid2016')
fig.show()
# Out:
# <div>                            <div id="9c121a72-055b-4b06-b1cc-8e1d640e6bce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c121a72-055b-4b06-b1cc-8e1d640e6bce")) {                    Plotly.newPlot(                        "9c121a72-055b-4b06-b1cc-8e1d640e6bce",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>signalavoid2016=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north
# ...

# %%
fig=px.box(df,x='region',y='wrongside2016')
fig.show()
# Out:
# <div>                            <div id="a0b4ff75-355c-45ed-ac6d-c6038c9c51bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0b4ff75-355c-45ed-ac6d-c6038c9c51bd")) {                    Plotly.newPlot(                        "a0b4ff75-355c-45ed-ac6d-c6038c9c51bd",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>wrongside2016=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north",
# ...

# %%
fig= px.box(df,x='region',y='lanejumping2016')
fig.show()
# Out:
# <div>                            <div id="a77635aa-8283-481b-b70a-734adc5f3601" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a77635aa-8283-481b-b70a-734adc5f3601")) {                    Plotly.newPlot(                        "a77635aa-8283-481b-b70a-734adc5f3601",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>lanejumping2016=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north
# ...

# %%
fig= px.box(df,x='region',y='overtaking2016')
fig.show()
# Out:
# <div>                            <div id="9b24cdc0-cb8b-40c1-bd58-fe4fb6edc863" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b24cdc0-cb8b-40c1-bd58-fe4fb6edc863")) {                    Plotly.newPlot(                        "9b24cdc0-cb8b-40c1-bd58-fe4fb6edc863",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>overtaking2016=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north"
# ...

# %%
fig = px.box(df,x='region',y='asleep2016')
fig.show()
# Out:
# <div>                            <div id="1154ea84-6cfe-463c-bf19-6a1a739e72c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1154ea84-6cfe-463c-bf19-6a1a739e72c9")) {                    Plotly.newPlot(                        "1154ea84-6cfe-463c-bf19-6a1a739e72c9",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>asleep2016=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north","no
# ...

# %%
fig=px.box(df,x='region',y='othercause2016')
fig.show()
# Out:
# <div>                            <div id="e9f88721-1e1d-409d-83f2-9ab1cd40325a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9f88721-1e1d-409d-83f2-9ab1cd40325a")) {                    Plotly.newPlot(                        "e9f88721-1e1d-409d-83f2-9ab1cd40325a",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>othercause2016=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["south","northeast","northeast","north","centre","west","west","north","north","north","centre","south","south","centre","west","northeast","northeast","east","northeast","centre","north","northwest","northeast","south","centre","east","north"
# ...

# %%
q = pd.pivot_table(df,index='region',values='alcintake2014')
q = q.sort_values(by='alcintake2014',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(alc in take 2014)',color='green')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='overspeed2014')
q = q.sort_values(by='overspeed2014',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(over speed 2014)',color='red')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='overtaking2014')
q = q.sort_values(by='overtaking2014',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(over taking 2014)',color='blue')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='lanejumping2014')
q = q.sort_values(by='lanejumping2014',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(lane jumping 2014)',color='orange')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='wrongside2014')
q = q.sort_values(by='wrongside2014',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(wrong side 2014)',color='yellow')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='signalavoid2014')
q = q.sort_values(by='signalavoid2014',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(signal avoid 2014)',color='pink')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='asleep2014')
q = q.sort_values(by='asleep2014',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(asleep 2014)',color='violet')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='othercause2014')
q = q.sort_values(by='othercause2014',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(other cause 2014)',color='grey')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
plt.rcParams['figure.figsize']= (20, 20)
fig = df.groupby('region')[['alcintake2014','overspeed2014','overtaking2014','lanejumping2014','wrongside2014','signalavoid2014','asleep2014','othercause2014']].agg('sum')
fig = fig.sort_values(by='region',ascending=False)
fig.plot(kind='bar',title='Total purchases by year')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='alcintake2016')
q = q.sort_values(by='alcintake2016',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(alc in take 2016)',color='red')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='overspeed2016')
q = q.sort_values(by='overspeed2016',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(over speed 2016)',color='pink')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='signalavoid2016')
q = q.sort_values(by='signalavoid2016',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(signal avoid 2016)',color='green')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='wrongside2016')
q = q.sort_values(by='wrongside2016',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(wrong side 2016)',color='gray')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='lanejumping2016')
q = q.sort_values(by='lanejumping2016',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(lane jumping 2016)',color='orange')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='overtaking2016')
q = q.sort_values(by='overtaking2016',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(over taking 2016)',color='blue')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='asleep2016')
q = q.sort_values(by='asleep2016',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(asleep 2016)',color='violet')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
q = pd.pivot_table(df,index='region',values='othercause2016')
q = q.sort_values(by='othercause2016',ascending=False)
p=q.plot(kind='bar',figsize=(20,5),title='Amount by region(other cause 2016)',color='yellow')
p.bar_label(p.containers[0],label_type='center')
plt.show()

# %%
plt.rcParams['figure.figsize']= (20, 20)
fig2 = df.groupby('region')[['alcintake2016','overspeed2016','overtaking2016','lanejumping2016','wrongside2016','signalavoid2016','asleep2016','othercause2016']].agg('sum')
fig2 = fig2.sort_values(by='region',ascending=False)
fig2.plot(kind='bar',title='Total purchases by year')
plt.show()
